# %%
 import json

# %%
f = open("./dataNew.json", "r")
strs=f.readlines()[0]

# %%
# parse x:
y = json.loads(strs)

# %%
y['DKI JAKARTA']
# Out:
# [{'last_date': '2020-06-09',
#   'kasus_total': 8355,
#   'kasus_tanpa_tgl': 489,
#   'kasus_dengan_tgl': 7866,
#   'meninggal_persen': 6.379413524835428,
#   'meninggal_tanpa_tgl': 20,
#   'meninggal_dengan_tgl': 513,
#   'sembuh_persen': 40.34709754637941,
#   'sembuh_tanpa_tgl': 39,
#   'sembuh_dengan_tgl': 3332,
#   'list_perkembangan': [{'tanggal': 1583020800000,
#     'KASUS': 3,
#     'MENINGGAL': 0,
#     'SEMBUH': 0,
#     'DIRAWAT_OR_ISOLASI': 3,
#     'AKUMULASI_KASUS': 3,
#     'AKUMULASI_SEMBUH': 0,
#     'AKUMULASI_MENINGGAL': 0,
#     'AKUMULASI_DIRAWAT_OR_ISOLASI': 3},
#    {'tanggal': 1583107200000,
#     'KASUS': 2,
#     'MENINGGAL': 0,
#     'SEMBUH': 0,
#     'DIRAWAT_OR_ISOLASI': 2,
#     'AKUMULASI_KASUS': 5,
#     'AKUMULASI_SEMBUH': 0,
#     'AKUMULASI_MENINGGAL': 0,
#     'AKUMULASI_DIRAWAT_OR_ISOLASI': 5},
#    {'tanggal': 1583193600000,
#     'KASUS': 2,
#     'MENINGGAL': 0,
#     'SEMBUH': 0,
#     'DIRAWAT_OR_ISOLASI': 2,
#     'AKUMULASI_KASUS': 7,
# ...
